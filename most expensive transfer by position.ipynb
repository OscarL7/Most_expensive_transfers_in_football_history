# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\PERSONAL\yolo\most_expensive_players\most expensive players.csv')
df
# Out:
#                 Player  Year            Fee    Position        Club from
# 0               Neymar  2017          €222m     Forward        Barcelona  \
# 1        Kylian Mbappe  2017  €145m (+€35m)     Forward           Monaco
# 2           Joao Felix  2019          €126m     Forward          Benfica
# 3       Enzo Fernandez  2023          €121m  Midfielder          Benfica
# 4    Philippe Coutinho  2018  €120m (+€40m)  Midfielder        Liverpool
# ..                 ...   ...            ...         ...              ...
# 96   Aaron Wan-Bissaka  2019           €50m    Fullback   Crystal Palace
# 97       Thomas Partey  2020           €50m  Midfielder  Atletico Madrid
# 98      Victor Osimhen  2020           €50m     Forward            Lille
# 99     Anthony Martial  2015         €49.3m     Forward           Monaco
# 100   Gylfi Sigurdsson  2017         €49.2m  Midfielder     Swansea City
#
#                Club to  Base Fee Add-ons Total Fee
# ...

# %% [markdown]
# 3 Most Expensive Players by position

# %%
forward = df[df['Position'] == 'Forward'].head(3)
forward
# Out:
#           Player  Year            Fee Position  Club from          Club to
# 0         Neymar  2017          €222m  Forward  Barcelona              PSG  \
# 1  Kylian Mbappe  2017  €145m (+€35m)  Forward     Monaco              PSG
# 2     Joao Felix  2019          €126m  Forward    Benfica  Atletico Madrid
#
#    Base Fee Add-ons Total Fee
# 0     222.0       0       222
# 1     145.0      35       180
# 2     126.0       0       126

# %%
midfielder = df[df['Position'] == 'Midfielder'].head(3)
midfielder
# Out:
#               Player  Year            Fee    Position    Club from
# 3     Enzo Fernandez  2023          €121m  Midfielder      Benfica  \
# 4  Philippe Coutinho  2018  €120m (+€40m)  Midfielder    Liverpool
# 6      Jack Grealish  2021          €117m  Midfielder  Aston Villa
#
#            Club to  Base Fee Add-ons Total Fee
# 3          Chelsea     121.0       0       121
# 4        Barcelona     120.0      40       160
# 6  Manchester City     117.0       0       117

# %%
fullback = df[df['Position'] == 'Defender'].head(3)
fullback
# Out:
#              Player  Year     Fee  Position       Club from
# 19    Harry Maguire  2019  €87.1m  Defender  Leicester City  \
# 23  Virgil van Dijk  2018  €84.5m  Defender     Southampton
# 25    Wesley Fofana  2022  €80.6m  Defender  Leicester City
#
#               Club to  Base Fee Add-ons Total Fee
# 19  Manchester United      87.1       0      87.1
# 23          Liverpool      84.5       0      84.5
# 25            Chelsea      80.6       0      80.6

# %%
goalkeeper = df[df['Position'] == 'Goalkeeper'].head(3)
goalkeeper
# Out:
#                Player  Year   Fee    Position      Club from    Club to
# 28  Kepa Arrizabalaga  2018  €80m  Goalkeeper  Athletic Club    Chelsea  \
# 40     Alisson Becker  2018  €73m  Goalkeeper           Roma  Liverpool
# 89   Gianluigi Buffon  2001  €52m  Goalkeeper          Parma   Juventus
#
#     Base Fee Add-ons Total Fee
# 28      80.0       0        80
# 40      73.0       0        73
# 89      52.0       0        52
